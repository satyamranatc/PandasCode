# %%
import pandas as pd
import numpy as np

# %%
x = np.array([1,2,3,4,5,6,7,8])
y = np.array([2,4,6,8,10,12,14,16])
df = pd.DataFrame({'x':x, 'y':y})
df
# Out:
#    x   y
# 0  1   2
# 1  2   4
# 2  3   6
# 3  4   8
# 4  5  10
# 5  6  12
# 6  7  14
# 7  8  16

# %%
df = pd.read_csv("./PandasData.csv")
df
# Out:
#      Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0         1  CA-2016-152156    11/8/16  11/11/16    Second Class    CG-12520
# 1         2  CA-2016-152156    11/8/16  11/11/16    Second Class    CG-12520
# 2         3  CA-2016-138688    6/12/16   6/16/16    Second Class    DV-13045
# 3         4  US-2015-108966   10/11/15  10/18/15  Standard Class    SO-20335
# 4         5  US-2015-108966   10/11/15  10/18/15  Standard Class    SO-20335
# ..      ...             ...        ...       ...             ...         ...
# 664     665  CA-2016-143308    11/4/16   11/4/16        Same Day    RC-19825
# 665     666  CA-2017-132682     6/8/17   6/10/17    Second Class    TH-21235
# 666     667  CA-2017-132682     6/8/17   6/10/17    Second Class    TH-21235
# 667     668  CA-2017-132682     6/8/17   6/10/17    Second Class    TH-21235
# 668     669  CA-2014-156314   12/24/14  12/26/14     First Class    RP-19390
#
# ...

# %%
df.head() # 5
df.head(10)
# Out:
#    Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156    11/8/16  11/11/16    Second Class    CG-12520
# 1       2  CA-2016-152156    11/8/16  11/11/16    Second Class    CG-12520
# 2       3  CA-2016-138688    6/12/16   6/16/16    Second Class    DV-13045
# 3       4  US-2015-108966   10/11/15  10/18/15  Standard Class    SO-20335
# 4       5  US-2015-108966   10/11/15  10/18/15  Standard Class    SO-20335
# 5       6  CA-2014-115812     6/9/14   6/14/14  Standard Class    BH-11710
# 6       7  CA-2014-115812     6/9/14   6/14/14  Standard Class    BH-11710
# 7       8  CA-2014-115812     6/9/14   6/14/14  Standard Class    BH-11710
# 8       9  CA-2014-115812     6/9/14   6/14/14  Standard Class    BH-11710
# 9      10  CA-2014-115812     6/9/14   6/14/14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# ...

# %%
df.sample(6) # Randomly select 6 rows
# Out:
#      Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 17       18  CA-2014-167164    5/13/14   5/15/14    Second Class    AG-10270
# 34       35  CA-2017-107727   10/19/17  10/23/17    Second Class    MA-17560
# 275     276  CA-2017-118136    9/16/17   9/17/17     First Class    BB-10990
# 65       66  CA-2015-135545   11/24/15  11/30/15  Standard Class    KM-16720
# 333     334  US-2016-150147    4/25/16   4/29/16    Second Class    JL-15850
# 581     582  CA-2017-145233    12/1/17   12/5/17  Standard Class    DV-13465
#
#         Customer Name      Segment        Country          City  ...  \
# 17    Alejandro Grove     Consumer  United States   West Jordan  ...
# 34       Matt Abelman  Home Office  United States       Houston  ...
# 275   Barry Blumstein    Corporate  United States     Inglewood  ...
# 65       Kunst Miller     Consumer  United States   Los Angeles  ...
# 333        John Lucas     Consumer  United States  Philadelphia  ...
# ...

# %%
df.tail() # 5
df.tail(10)
# Out:
#      Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 659     660  CA-2015-146563    8/24/15   8/28/15  Standard Class    CB-12025
# 660     661  CA-2015-146563    8/24/15   8/28/15  Standard Class    CB-12025
# 661     662  CA-2015-146563    8/24/15   8/28/15  Standard Class    CB-12025
# 662     663  CA-2015-146563    8/24/15   8/28/15  Standard Class    CB-12025
# 663     664  CA-2016-123666    3/26/16   3/30/16  Standard Class    SP-20545
# 664     665  CA-2016-143308    11/4/16   11/4/16        Same Day    RC-19825
# 665     666  CA-2017-132682     6/8/17   6/10/17    Second Class    TH-21235
# 666     667  CA-2017-132682     6/8/17   6/10/17    Second Class    TH-21235
# 667     668  CA-2017-132682     6/8/17   6/10/17    Second Class    TH-21235
# 668     669  CA-2014-156314   12/24/14  12/26/14     First Class    RP-19390
#
#          Customer Name    Segment        Country           City  ...  \
# ...

# %%
df.shape
# Out:
# (669, 21)

# %%
df.describe()
# Out:
#            Row ID   Postal Code        Sales    Quantity    Discount  \
# count  669.000000    669.000000   669.000000  669.000000  669.000000
# mean   335.000000  55981.041854   253.323248    3.904335    0.174454
# std    193.267949  31071.419797   606.469066    2.349633    0.212393
# min      1.000000   1841.000000     1.248000    1.000000    0.000000
# 25%    168.000000  28205.000000    18.648000    2.000000    0.000000
# 50%    335.000000  60505.000000    62.982000    3.000000    0.200000
# 75%    502.000000  85705.000000   233.860000    5.000000    0.200000
# max    669.000000  98661.000000  8159.952000   14.000000    0.800000
#
#             Profit
# count   669.000000
# mean     19.387223
# std     214.350443
# min   -1665.052200
# 25%       1.200600
# 50%       7.884000
# 75%      26.271000
# max    3177.475000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         669 non-null    int64
#  1   Order ID       669 non-null    object
#  2   Order Date     669 non-null    object
#  3   Ship Date      669 non-null    object
#  4   Ship Mode      669 non-null    object
#  5   Customer ID    669 non-null    object
#  6   Customer Name  669 non-null    object
#  7   Segment        669 non-null    object
#  8   Country        669 non-null    object
#  9   City           669 non-null    object
#  10  State          669 non-null    object
#  11  Postal Code    669 non-null    int64
#  12  Region         669 non-null    object
#  13  Product ID     669 non-null    object
#  14  Category       669 non-null    object
#  15  Sub-Category   669 non-null    object
#  16  Product Name   669 non-null    object
# ...

# %%
df["Profit"]
df["Profit"][3]
df["Profit"][0:40]
df["Profit"][0:40:2]
# Out:
# 0      41.9136
# 2       6.8714
# 4       2.5164
# 6       1.9656
# 8       5.7825
# 10     85.3092
# 12      5.4432
# 14   -123.8580
# 16     13.3176
# 18      2.4824
# 20      7.3840
# 22     15.6884
# 24    240.2649
# 26     11.7741
# 28     -7.0532
# 30      1.1016
# 32     -5.7150
# 34      9.9468
# 36   -147.9630
# 38    -46.9764
# Name: Profit, dtype: float64

# %%
df[df["Profit"]>0]
df["Profit"][df["Profit"]>0]
# Out:
# 0       41.9136
# 1      219.5820
# 2        6.8714
# 4        2.5164
# 5       14.1694
#          ...
# 664      5.2626
# 665      2.0790
# 666     28.7064
# 667     28.6182
# 668      8.7285
# Name: Profit, Length: 524, dtype: float64

# %%
df["Profit"].max()
# Out:
# 3177.475

# %%
df["Profit"].min()
# Out:
# -1665.0522

# %%
df["Profit"].mean()
# Out:
# 19.38722257100149

# %%
df["Profit"].mode()
# Out:
# 0    0.0
# Name: Profit, dtype: float64

# %%
df["Profit"].median()
# Out:
# 7.884

# %%
df.dropna()
df.fillna(200)
# Out:
#      Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0         1  CA-2016-152156    11/8/16  11/11/16    Second Class    CG-12520
# 1         2  CA-2016-152156    11/8/16  11/11/16    Second Class    CG-12520
# 2         3  CA-2016-138688    6/12/16   6/16/16    Second Class    DV-13045
# 3         4  US-2015-108966   10/11/15  10/18/15  Standard Class    SO-20335
# 4         5  US-2015-108966   10/11/15  10/18/15  Standard Class    SO-20335
# ..      ...             ...        ...       ...             ...         ...
# 664     665  CA-2016-143308    11/4/16   11/4/16        Same Day    RC-19825
# 665     666  CA-2017-132682     6/8/17   6/10/17    Second Class    TH-21235
# 666     667  CA-2017-132682     6/8/17   6/10/17    Second Class    TH-21235
# 667     668  CA-2017-132682     6/8/17   6/10/17    Second Class    TH-21235
# 668     669  CA-2014-156314   12/24/14  12/26/14     First Class    RP-19390
#
# ...

# %%
df["Profit"].isna().sum()
# Out:
# 0
